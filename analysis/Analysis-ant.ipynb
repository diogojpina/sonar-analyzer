# %% [markdown]
# # 1.BLOCKER and CRITICAL Ant issues analysis

# %% [markdown]
# ## Loading data

# %% [markdown]
# Query used to get all the described issues and connection string to the database (Postgres):

# %%
query_issues = '''
    select
        i.kee as uuid,
        i.severity,
        i.message as message,
        i.line as line,
        p.name as file_name,
        m.name as metric,
        l.value as value
    from
        issues i 
        inner join projects p on i.component_uuid = p.uuid
        inner join live_measures l on i.component_uuid = l.component_uuid
        inner join metrics m on l.metric_id = m.id
    where
        i.project_uuid = 'AWwKYKvNNVnBRBMSHei7'
        -- dívidas técnicas com tipo BLOCKER ou CRITICAL
        and i.severity in ('BLOCKER', 'CRITICAL')
        and l.metric_id in (3, 18, 47) -- metricas que se deseja extrair do arquivo em questao'''

connection_url = 'postgresql://sonar:sonar@localhost/sonar'

# %% [markdown]
# Importing analysis libraries:

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss

# %% [markdown]
# Loading the results into a Dataframe:

# %%
df_issues = pd.read_sql(query_issues, connection_url)
df_issues.head()
# Out:
#                    uuid  severity  \
# 0  AWwKYN7qIFKoM8TmMFvQ  CRITICAL
# 1  AWwKYN7qIFKoM8TmMFvQ  CRITICAL
# 2  AWwKYN7qIFKoM8TmMFvO  CRITICAL
# 3  AWwKYN7qIFKoM8TmMFvO  CRITICAL
# 4  AWwKYN7qIFKoM8TmMFvM  CRITICAL
#
#                                              message  line     file_name  \
# 0  Refactor this method to reduce its Cognitive C...   789  ZipFile.java
# 1  Refactor this method to reduce its Cognitive C...   789  ZipFile.java
# 2      Do not override the Object.finalize() method.   409  ZipFile.java
# 3      Do not override the Object.finalize() method.   409  ZipFile.java
# 4         Make sure this file handling is safe here.   178  ZipFile.java
#
#        metric  value
# 0       ncloc  577.0
# 1  complexity   96.0
# 2       ncloc  577.0
# 3  complexity   96.0
# 4       ncloc  577.0

# %% [markdown]
# ## Insights

# %% [markdown]
# Size of the Dataframe

# %%
df_issues.shape
# Out:
# (2369, 7)

# %% [markdown]
# Issues count per severity

# %%
df_issues.drop_duplicates('uuid').groupby('severity').count().uuid
# Out:
# severity
# BLOCKER      88
# CRITICAL    992
# Name: uuid, dtype: int64

# %% [markdown]
# Descriptive statistics per metric type (complexity and ncloc)

# %%
df_issues.loc[df_issues['metric'] == 'complexity'].drop_duplicates('file_name')['value'].describe()
# Out:
#                       uuid  severity  \
# 1     AWwKYN7qIFKoM8TmMFvQ  CRITICAL
# 3     AWwKYN7qIFKoM8TmMFvO  CRITICAL
# 5     AWwKYN7qIFKoM8TmMFvM  CRITICAL
# 7     AWwKYN7qIFKoM8TmMFvL  CRITICAL
# 9     AWwKYN7hIFKoM8TmMFvE  CRITICAL
# 11    AWwKYN7hIFKoM8TmMFvA   BLOCKER
# 13    AWwKYN7hIFKoM8TmMFu-   BLOCKER
# 15    AWwKYN7hIFKoM8TmMFu9   BLOCKER
# 17    AWwKYN7hIFKoM8TmMFu8   BLOCKER
# 19    AWwKYN7hIFKoM8TmMFu7  CRITICAL
# 21    AWwKYN7cIFKoM8TmMFu6  CRITICAL
# 23    AWwKYN64IFKoM8TmMFur   BLOCKER
# 25    AWwKYN6yIFKoM8TmMFup  CRITICAL
# 27    AWwKYN6tIFKoM8TmMFui   BLOCKER
# 29    AWwKYN6pIFKoM8TmMFug  CRITICAL
# 31    AWwKYN6pIFKoM8TmMFuf  CRITICAL
# 33    AWwKYN6pIFKoM8TmMFue  CRITICAL
# 35    AWwKYN6kIFKoM8TmMFud   BLOCKER
# 37    AWwKYN6kIFKoM8TmMFuc  CRITICAL
# 39    AWwKYN6hIFKoM8TmMFua  CRITICAL
# 41    AWwKYN6aIFKoM8TmMFuY   BLOCKER
# 43    AWwKYN6aIFKoM8TmMFuX  CRITICAL
# 45    AWwKYN6MIFKoM8TmMFuT  CRITICAL
# 47    AWwKYN6DIFKoM8TmMFuL  CRITICAL
# 49    AWwKYN6DIFKoM8TmMFuJ  CRITICAL
# 51    AWwKYN6DIFKoM8TmMFuG  CRITICAL
# 53    AWwKYN6DIFKoM8TmMFuF  CRITICAL
# 55    AWwKYN6DIFKoM8TmMFuD  CRITICAL
# 57    AWwKYN6DIFKoM8TmMFuB  CRITICAL
# 59    AWwKYN6DIFKoM8TmMFuA  CRITICAL
# ...                    ...       ...
# 2301  AWwKYMwWIFKoM8TmME_4   BLOCKER
# 2303  AWwKYMwWIFKoM8TmME_2  CRITICAL
# 2305  AWwKYMwWIFKoM8TmME_y  CRITICAL
# 2307  AWwKYMwNIFKoM8TmME_w  CRITICAL
# 2309  AWwKYMv-IFKoM8TmME_t  CRITICAL
# 2311  AWwKYMv-IFKoM8TmME_s   BLOCKER
# 2313  AWwKYMv2IFKoM8TmME_i   BLOCKER
# 2315  AWwKYMv2IFKoM8TmME_h  CRITICAL
# 2317  AWwKYMvxIFKoM8TmME_g   BLOCKER
# 2319  AWwKYMvkIFKoM8TmME_f   BLOCKER
# 2321  AWwKYMvQIFKoM8TmME_d   BLOCKER
# 2323  AWwKYMvEIFKoM8TmME_X  CRITICAL
# 2325  AWwKYMvEIFKoM8TmME_W  CRITICAL
# 2328  AWwKYMusIFKoM8TmME_T  CRITICAL
# 2331  AWwKYMusIFKoM8TmME_Q  CRITICAL
# 2334  AWwKYMusIFKoM8TmME_N  CRITICAL
# 2337  AWwKYMusIFKoM8TmME_M  CRITICAL
# 2340  AWwKYMusIFKoM8TmME_L  CRITICAL
# 2343  AWwKYMurIFKoM8TmME_J   BLOCKER
# 2346  AWwKYMurIFKoM8TmME_I  CRITICAL
# 2349  AWwKYMurIFKoM8TmME_H  CRITICAL
# 2352  AWwKYMurIFKoM8TmME_D  CRITICAL
# 2354  AWwKYMuYIFKoM8TmME_B  CRITICAL
# 2356  AWwKYMuYIFKoM8TmME-_  CRITICAL
# 2358  AWwKYMlkIFKoM8TmME8_  CRITICAL
# 2360  AWwKYMktIFKoM8TmME85   BLOCKER
# 2362  AWwKYMZIIFKoM8TmME8s  CRITICAL
# 2364  AWwKYMZHIFKoM8TmME8r  CRITICAL
# 2366  AWwKYMZHIFKoM8TmME8q  CRITICAL
# 2368  AWwKYMZHIFKoM8TmME8p   BLOCKER
#
#                                                 message  line  \
# 1     Refactor this method to reduce its Cognitive C...   789
# 3         Do not override the Object.finalize() method.   409
# 5            Make sure this file handling is safe here.   178
# 7            Make sure this file handling is safe here.   164
# 9     Refactor this method to reduce its Cognitive C...   732
# 11    Remove this "clone" implementation; use a copy...   178
# 13         "name" is the name of a field in "ZipEntry".    79
# 15         "size" is the name of a field in "ZipEntry".    72
# 17       "method" is the name of a field in "ZipEntry".    64
# 19                                   Rename this class.    49
# 21                   Move constants to a class or enum.    26
# 23    Remove this "clone" implementation; use a copy...   150
# 25    Refactor this method to reduce its Cognitive C...   219
# 27    Remove this "clone" implementation; use a copy...   185
# 29    Rename this constant name to match the regular...    46
# 31    Rename this constant name to match the regular...    41
# 33    Rename this constant name to match the regular...    33
# 35    Remove this "clone" implementation; use a copy...   204
# 37    Add a nested comment explaining why this metho...    57
# 39    Refactor this method to reduce its Cognitive C...   133
# 41    Remove this "clone" implementation; use a copy...   342
# 43    Add a nested comment explaining why this metho...    97
# 45         Make sure that sockets are used safely here.   379
# 47    Make sure that this dynamic injection or execu...  1402
# 49    Refactor this method to reduce its Cognitive C...  1238
# 51    Refactor this method to reduce its Cognitive C...  1009
# 53    Refactor this method to reduce its Cognitive C...   882
# 55    Refactor this method to reduce its Cognitive C...   724
# 57           Make sure this file handling is safe here.   553
# 59    Refactor this method to reduce its Cognitive C...   514
# ...                                                 ...   ...
# 2301  Remove this "clone" implementation; use a copy...   477
# 2303         Make sure this file handling is safe here.   334
# 2305  Define a constant instead of duplicating this ...   635
# 2307  Make sure that this dynamic injection or execu...   267
# 2309  Refactor this method to reduce its Cognitive C...   515
# 2311  Remove this "clone" implementation; use a copy...   475
# 2313  Remove this "clone" implementation; use a copy...   557
# 2315  Refactor this method to reduce its Cognitive C...   482
# 2317  Remove this "clone" implementation; use a copy...    54
# 2319  Remove this "clone" implementation; use a copy...   260
# 2321  Remove this "clone" implementation; use a copy...    55
# 2323  Add a nested comment explaining why this metho...    59
# 2325  Add a nested comment explaining why this metho...    51
# 2328         Make sure this file handling is safe here.  1102
# 2331  Refactor this method to reduce its Cognitive C...   994
# 2334         Make sure this file handling is safe here.   673
# 2337         Make sure this file handling is safe here.   651
# 2340  Refactor this method to reduce its Cognitive C...   622
# 2343      Disable XML external entity (XXE) processing.   571
# 2346  Make sure that this dynamic injection or execu...   523
# 2349  Make sure that this dynamic injection or execu...   513
# 2352  Define a constant instead of duplicating this ...   817
# 2354  Refactor this method to reduce its Cognitive C...   592
# 2356  Refactor this method to reduce its Cognitive C...   460
# 2358      Do not override the Object.finalize() method.   196
# 2360  Remove this "clone" implementation; use a copy...   223
# 2362  Rename this constant name to match the regular...   196
# 2364  Rename this constant name to match the regular...   196
# 2366  Rename this constant name to match the regular...   196
# 2368  Remove this "clone" implementation; use a copy...   114
#
#                                     file_name      metric  value
# 1                                ZipFile.java  complexity   96.0
# 3                                ZipFile.java  complexity   96.0
# 5                                ZipFile.java  complexity   96.0
# 7                                ZipFile.java  complexity   96.0
# 9                               ZipEntry.java  complexity  117.0
# 11                              ZipEntry.java  complexity  117.0
# 13                              ZipEntry.java  complexity  117.0
# 15                              ZipEntry.java  complexity  117.0
# 17                              ZipEntry.java  complexity  117.0
# 19                              ZipEntry.java  complexity  117.0
# 21                              UnixStat.java  complexity    0.0
# 23                              ZipShort.java  complexity   14.0
# 25    Zip64ExtendedInformationExtraField.java  complexity   50.0
# 27                               ZipLong.java  complexity   15.0
# 29                             Zip64Mode.java  complexity    0.0
# 31                             Zip64Mode.java  complexity    0.0
# 33                             Zip64Mode.java  complexity    0.0
# 35                     GeneralPurposeBit.java  complexity   29.0
# 37                     GeneralPurposeBit.java  complexity   29.0
# 39                       ExtraFieldUtils.java  complexity   28.0
# 41                         AsiExtraField.java  complexity   25.0
# 43                         AsiExtraField.java  complexity   25.0
# 45                           MailMessage.java  complexity   63.0
# 47                        AntClassLoader.java  complexity  193.0
# 49                        AntClassLoader.java  complexity  193.0
# 51                        AntClassLoader.java  complexity  193.0
# 53                        AntClassLoader.java  complexity  193.0
# 55                        AntClassLoader.java  complexity  193.0
# 57                        AntClassLoader.java  complexity  193.0
# 59                        AntClassLoader.java  complexity  193.0
# ...                                       ...         ...    ...
# 2301                                Path.java  complexity  110.0
# 2303                                Path.java  complexity  110.0
# 2305                                Path.java  complexity  110.0
# 2307                              Mapper.java  complexity   48.0
# 2309                           FilterSet.java  complexity   82.0
# 2311                           FilterSet.java  complexity   82.0
# 2313                         Commandline.java  complexity  101.0
# 2315                         Commandline.java  complexity  101.0
# 2317                             FileSet.java  complexity   11.0
# 2319                          TarFileSet.java  complexity   37.0
# 2321                              DirSet.java  complexity   12.0
# 2323                       CutDirsMapper.java  complexity    9.0
# 2325                       CutDirsMapper.java  complexity    9.0
# 2328                          XMLCatalog.java  complexity   92.0
# 2331                          XMLCatalog.java  complexity   92.0
# 2334                          XMLCatalog.java  complexity   92.0
# 2337                          XMLCatalog.java  complexity   92.0
# 2340                          XMLCatalog.java  complexity   92.0
# 2343                          XMLCatalog.java  complexity   92.0
# 2346                          XMLCatalog.java  complexity   92.0
# 2349                          XMLCatalog.java  complexity   92.0
# 2352                          XMLCatalog.java  complexity   92.0
# 2354                   RedirectorElement.java  complexity  113.0
# 2356                   RedirectorElement.java  complexity  113.0
# 2358                         ZipResource.java  complexity   27.0
# 2360     BaseResourceCollectionContainer.java  complexity   35.0
# 2362                    MultiRootFileSet.java  complexity   38.0
# 2364                    MultiRootFileSet.java  complexity   38.0
# 2366                    MultiRootFileSet.java  complexity   38.0
# 2368                    MultiRootFileSet.java  complexity   38.0
#
# [1080 rows x 7 columns]

# %%
df_issues.loc[df_issues['metric'] == 'ncloc', 'value'].describe()
# Out:
# count    1080.000000
# mean      441.074074
# std       380.976573
# min         5.000000
# 25%       151.000000
# 50%       333.000000
# 75%       652.000000
# max      1667.000000
# Name: value, dtype: float64

# %%
df_issues.loc[df_issues['metric'] == 'duplicated_lines', 'value'].describe()
# Out:
# count    209.000000
# mean     259.401914
# std      347.358232
# min       18.000000
# 25%       32.000000
# 50%       67.000000
# 75%      268.000000
# max      961.000000
# Name: value, dtype: float64

# %% [markdown]
# ---
# # 2.Same analysis, but with all the files in the project for comparison

# %% [markdown]
# ## Loading data

# %% [markdown]
# Query used to get all the described issues and connection string to the database (Postgres):

# %%
query_all = """
    select
        p.name as file_name,
        m.name as metric,
        l.value as value
    from 
        projects p
        inner join live_measures l on p.uuid = l.component_uuid
        inner join metrics m on l.metric_id = m.id
    where
        p.project_uuid = 'AWwKYKvNNVnBRBMSHei7'
        and l.metric_id in (3, 18, 47) -- metricas que se deseja extrair do arquivo em questao
        and p."scope" = 'FIL' and p.qualifier = 'FIL'"""

# %% [markdown]
# Loading the results into a Dataframe:

# %%
df_all = pd.read_sql(query_all, connection_url)
df_all.head()
# Out:
#                file_name      metric  value
# 0  MultiRootFileSet.java  complexity   38.0
# 1  MultiRootFileSet.java       ncloc  155.0
# 2              Type.java  complexity   10.0
# 3              Type.java       ncloc   40.0
# 4               Not.java  complexity    5.0

# %% [markdown]
# ## Insights

# %% [markdown]
# Size of the Dataframe

# %%
df_all.shape
# Out:
# (1939, 3)

# %% [markdown]
# Descriptive statistics per metric type (complexity and ncloc)

# %%
df_all.loc[df_all['metric'] == 'complexity', 'value'].describe()
# Out:
# count    923.000000
# mean      27.565547
# std       43.122798
# min        0.000000
# 25%        4.000000
# 50%       13.000000
# 75%       31.000000
# max      401.000000
# Name: value, dtype: float64

# %%
df_all.loc[df_all['metric'] == 'ncloc', 'value'].describe()
# Out:
# count     925.000000
# mean      121.480000
# std       176.656522
# min         1.000000
# 25%        24.000000
# 50%        61.000000
# 75%       134.000000
# max      1667.000000
# Name: value, dtype: float64

# %%
df_all.loc[df_all['metric'] == 'duplicated_lines', 'value'].describe()
# Out:
# count     91.000000
# mean      77.197802
# std      128.908083
# min       11.000000
# 25%       26.500000
# 50%       42.000000
# 75%       75.500000
# max      961.000000
# Name: value, dtype: float64

# %% [markdown]
# ---
# # 3.Analysing metrics per issue type (rule)

# %% [markdown]
# Now, let's add the columns `rule_id` and replace `message` to (rule) `name` in the query.
#
# This queries all the issues (technical debt) of types 'BLOCKER' and 'CRITICAL' and gets the rule that it is breaking. This way, we'll be able to get the metrics (like "complexity" or "ncloc") per rule and make the analysis.

# %%
query_rules = '''
    select
        i.rule_id,
        r.name,
        m.name as metric,
        l.value as value
    from
        issues i 
        inner join rules r on i.rule_id = r.id
        inner join projects p on i.component_uuid = p.uuid
        inner join live_measures l on i.component_uuid = l.component_uuid
        inner join metrics m on l.metric_id = m.id
    where
        i.project_uuid = 'AWwKYKvNNVnBRBMSHei7'
        -- dívidas técnicas com tipo BLOCKER ou CRITICAL
        and i.severity in ('BLOCKER', 'CRITICAL')
        and l.metric_id in (3, 18)--, 47) -- metricas que se deseja extrair do arquivo em questao'''

# %% [markdown]
# Loading the data

# %%
df_rules = pd.read_sql(query_rules, connection_url)
df_rules.head()
# Out:
#    rule_id                                               name      metric  \
# 0     5510  Cognitive Complexity of methods should not be ...       ncloc
# 1     5510  Cognitive Complexity of methods should not be ...  complexity
# 2     5245  The Object.finalize() method should not be ove...       ncloc
# 3     5245  The Object.finalize() method should not be ove...  complexity
# 4     5370               Handling files is security-sensitive       ncloc
#
#    value
# 0  577.0
# 1   96.0
# 2  577.0
# 3   96.0
# 4  577.0

# %% [markdown]
# ## Insights

# %% [markdown]
# General information

# %%
df_rules['name'].unique()
# Out:
# array(['Cognitive Complexity of methods should not be too high',
#        'The Object.finalize() method should not be overriden',
#        'Handling files is security-sensitive',
#        '"clone" should not be overridden',
#        'Child class fields should not shadow parent class fields',
#        'Class names should not shadow interfaces or superclasses',
#        'Constants should not be defined in interfaces',
#        'Constant names should comply with a naming convention',
#        'Methods should not be empty',
#        'Using Sockets is security-sensitive',
#        'Dynamically executing code is security-sensitive',
#        'Expanding archive files is security-sensitive',
#        'Using command line arguments is security-sensitive',
#        'String literals should not be duplicated',
#        'Untrusted XML should be parsed with a local, static DTD',
#        '"switch" statements should have "default" clauses',
#        'Reading the Standard Input is security-sensitive',
#        'Using regular expressions is security-sensitive',
#        'Methods and field names should not be the same or differ only by capitalization',
#        '"ThreadGroup" should not be used',
#        'Generic wildcard types should not be used in return parameters',
#        'XML transformers should be secured',
#        'Try-with-resources should be used',
#        'Fields in a "Serializable" class should either be transient or serializable',
#        'Changing or bypassing accessibility is security-sensitive',
#        'Null should not be returned from a "Boolean" method',
#        'Getters and setters should access the expected fields',
#        'Executing OS commands is security-sensitive',
#        'Basic authentication should not be used',
#        'Execution of the Garbage Collector should be triggered only by the JVM',
#        'Using pseudorandom number generators (PRNGs) is security-sensitive',
#        'Executing XPath expressions is security-sensitive',
#        '"indexOf" checks should not be for positive numbers',
#        'Hashing data is security-sensitive', 'Resources should be closed',
#        'Exceptions should not be thrown in finally blocks',
#        'Jump statements should not occur in "finally" blocks',
#        'Methods returns should not be invariant',
#        '"Random" objects should be reused'], dtype=object)

# %%
df_rules['name'].unique().shape
# Out:
# (39,)

# %% [markdown]
# ## Grouping by `rule_id` and calculating the metric's statistics

# %%
df_rules_grouped = df_rules.groupby(['rule_id', 'name', 'metric'])

# %% [markdown]
# Some counting

# %%
df_rules_grouped.count().sort_values('value', ascending=False).head(10)
# Out:
#                                                                        value
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc         292
#                                                            complexity    292
# 5370    Handling files is security-sensitive               ncloc         197
#                                                            complexity    197
# 5413    Methods should not be empty                        ncloc         128
#                                                            complexity    128
# 5098    String literals should not be duplicated           complexity    119
#                                                            ncloc         119
# 5297    Dynamically executing code is security-sensitive   ncloc          80
#                                                            complexity     80

# %% [markdown]
# Some statistics

# %%
df_agg = df_rules_grouped.agg(['describe'])
df_agg.columns = df_agg.columns.droplevel().droplevel()

df_agg.sort_values(['count', 'rule_id', 'metric'], ascending=False).head(16)
# Out:
#                                                                        count  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       292.0
#                                                            complexity  292.0
# 5370    Handling files is security-sensitive               ncloc       197.0
#                                                            complexity  197.0
# 5413    Methods should not be empty                        ncloc       128.0
#                                                            complexity  128.0
# 5098    String literals should not be duplicated           ncloc       119.0
#                                                            complexity  119.0
# 5297    Dynamically executing code is security-sensitive   ncloc        80.0
#                                                            complexity   80.0
# 5298    "clone" should not be overridden                   ncloc        33.0
#                                                            complexity   33.0
# 5050    Try-with-resources should be used                  ncloc        29.0
#                                                            complexity   29.0
# 5574    Constant names should comply with a naming conv... ncloc        25.0
#                                                            complexity   25.0
#
#                                                                              mean  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       541.845890
#                                                            complexity  130.458904
# 5370    Handling files is security-sensitive               ncloc       493.467005
#                                                            complexity  116.771574
# 5413    Methods should not be empty                        ncloc       260.648438
#                                                            complexity   57.476562
# 5098    String literals should not be duplicated           ncloc       545.529412
#                                                            complexity  129.033613
# 5297    Dynamically executing code is security-sensitive   ncloc       297.312500
#                                                            complexity   63.437500
# 5298    "clone" should not be overridden                   ncloc       230.666667
#                                                            complexity   60.636364
# 5050    Try-with-resources should be used                  ncloc       648.310345
#                                                            complexity  153.068966
# 5574    Constant names should comply with a naming conv... ncloc       114.760000
#                                                            complexity   25.240000
#
#                                                                               std  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       404.334276
#                                                            complexity   98.710039
# 5370    Handling files is security-sensitive               ncloc       358.039097
#                                                            complexity   91.529596
# 5413    Methods should not be empty                        ncloc       269.518310
#                                                            complexity   61.949810
# 5098    String literals should not be duplicated           ncloc       395.591722
#                                                            complexity   97.491758
# 5297    Dynamically executing code is security-sensitive   ncloc       283.405135
#                                                            complexity   67.151603
# 5298    "clone" should not be overridden                   ncloc       153.703584
#                                                            complexity   41.858256
# 5050    Try-with-resources should be used                  ncloc       574.348208
#                                                            complexity  142.408851
# 5574    Constant names should comply with a naming conv... ncloc       112.286568
#                                                            complexity   32.720126
#
#                                                                         min  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       53.0
#                                                            complexity   9.0
# 5370    Handling files is security-sensitive               ncloc       15.0
#                                                            complexity   4.0
# 5413    Methods should not be empty                        ncloc        5.0
#                                                            complexity   1.0
# 5098    String literals should not be duplicated           ncloc       22.0
#                                                            complexity   3.0
# 5297    Dynamically executing code is security-sensitive   ncloc       32.0
#                                                            complexity   2.0
# 5298    "clone" should not be overridden                   ncloc       45.0
#                                                            complexity  10.0
# 5050    Try-with-resources should be used                  ncloc       28.0
#                                                            complexity   2.0
# 5574    Constant names should comply with a naming conv... ncloc        6.0
#                                                            complexity   0.0
#
#                                                                           25%  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       248.25
#                                                            complexity   57.75
# 5370    Handling files is security-sensitive               ncloc       231.00
#                                                            complexity   49.00
# 5413    Methods should not be empty                        ncloc        85.00
#                                                            complexity   21.00
# 5098    String literals should not be duplicated           ncloc       249.00
#                                                            complexity   61.00
# 5297    Dynamically executing code is security-sensitive   ncloc        90.00
#                                                            complexity   16.50
# 5298    "clone" should not be overridden                   ncloc       111.00
#                                                            complexity   25.00
# 5050    Try-with-resources should be used                  ncloc       111.00
#                                                            complexity   19.00
# 5574    Constant names should comply with a naming conv... ncloc        44.00
#                                                            complexity    6.00
#
#                                                                          50%  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       434.0
#                                                            complexity  107.0
# 5370    Handling files is security-sensitive               ncloc       391.0
#                                                            complexity   80.0
# 5413    Methods should not be empty                        ncloc       151.0
#                                                            complexity   31.5
# 5098    String literals should not be duplicated           ncloc       434.0
#                                                            complexity   99.0
# 5297    Dynamically executing code is security-sensitive   ncloc       191.0
#                                                            complexity   40.0
# 5298    "clone" should not be overridden                   ncloc       177.0
#                                                            complexity   46.0
# 5050    Try-with-resources should be used                  ncloc       483.0
#                                                            complexity  112.0
# 5574    Constant names should comply with a naming conv... ncloc        67.0
#                                                            complexity    6.0
#
#                                                                            75%  \
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc        710.50
#                                                            complexity   177.00
# 5370    Handling files is security-sensitive               ncloc        721.00
#                                                            complexity   179.00
# 5413    Methods should not be empty                        ncloc        289.00
#                                                            complexity    62.00
# 5098    String literals should not be duplicated           ncloc        758.00
#                                                            complexity   173.50
# 5297    Dynamically executing code is security-sensitive   ncloc        388.00
#                                                            complexity    80.75
# 5298    "clone" should not be overridden                   ncloc        335.00
#                                                            complexity   101.00
# 5050    Try-with-resources should be used                  ncloc       1235.00
#                                                            complexity   295.00
# 5574    Constant names should comply with a naming conv... ncloc        155.00
#                                                            complexity    38.00
#
#                                                                           max
# rule_id name                                               metric
# 5510    Cognitive Complexity of methods should not be t... ncloc       1667.0
#                                                            complexity   401.0
# 5370    Handling files is security-sensitive               ncloc       1667.0
#                                                            complexity   401.0
# 5413    Methods should not be empty                        ncloc       1193.0
#                                                            complexity   293.0
# 5098    String literals should not be duplicated           ncloc       1667.0
#                                                            complexity   401.0
# 5297    Dynamically executing code is security-sensitive   ncloc       1245.0
#                                                            complexity   295.0
# 5298    "clone" should not be overridden                   ncloc        542.0
#                                                            complexity   137.0
# 5050    Try-with-resources should be used                  ncloc       1667.0
#                                                            complexity   401.0
# 5574    Constant names should comply with a naming conv... ncloc        531.0
#                                                            complexity   153.0

# %% [markdown]
# # REDO

# %% [markdown]
# Now let's compute some **correlation**:

# %% [markdown]
# First we need a correlation function for categorical variables, we're gonna use Cramers V

# %%
def cramers_corrected_stat(confusion_matrix):
    """ calculate Cramers V statistic for categorial-categorial association.
        uses correction from Bergsma and Wicher, 
        Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min( (kcorr-1), (rcorr-1)))

# %% [markdown]
# Then, let's calculate the confusion matrix for each metric

# %%
df_complexity = df_rules.loc[df_rules['metric'] == 'complexity', ['name', 'value']]
df_ncloc = df_rules.loc[df_rules['metric'] == 'ncloc', ['name', 'value']]
conf_matrix_complexity = pd.crosstab(df_complexity['name'], df_complexity['value'])
conf_matrix_ncloc = pd.crosstab(df_ncloc['name'], df_ncloc['value'])

# %% [markdown]
# Finally, the correlation:

# %%
# complexity
cramers_corrected_stat(conf_matrix_complexity)
# Out:
# 0.2966368467722552

# %%
# ncloc
cramers_corrected_stat(conf_matrix_ncloc)
# Out:
# 0.35527362654266226
